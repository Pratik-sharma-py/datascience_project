# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive -name "*.ipynb" 2>/dev/null
# Out:
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/visu_practise.ipynb
# /content/drive/MyDrive/Colab Notebooks/Projectset.ipynb
# /content/drive/MyDrive/Colab Notebooks/next2.ipynb
# /content/drive/MyDrive/Colab Notebooks/range_fun.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Python.ipynb
# /content/drive/MyDrive/Colab Notebooks/student_visu.ipynb
# /content/drive/MyDrive/Colab Notebooks/sample.ipynb
# /content/drive/MyDrive/Colab Notebooks/population_sampling_demo.ipynb
# /content/drive/MyDrive/Colab Notebooks/sample-main.ipynb
# /content/drive/MyDrive/Colab Notebooks/python_yt.ipynb
# /content/drive/MyDrive/Colab Notebooks/stats.ipynb
# /content/drive/MyDrive/Colab Notebooks/.ipynb
# /content/drive/MyDrive/Colab Notebooks/cov_project.ipynb
# /content/drive/MyDrive/Colab Notebooks/Stats_project2.ipynb
# ...

# %%
# !ls /content
# Out:
# datascience_project  drive  sample_data  wine_data.csv

# %%
# !git config --global user.email "pratikacharya527@email.com"
# !git config --global user.name "Pratik-sharma-py"

# %%
# token removed for security
# Out:
# fatal: destination path '/content/datascience_project' already exists and is not an empty directory.

# %%
# !ls /content
# Out:
# datascience_project  drive  sample_data  wine_data.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/wine_data.csv',header = None, usecols=[0,1,2])
data.columns =['Class label','Alcohol','Malic acid']

# %%
data
# Out:
#      Class label  Alcohol  Malic acid
# 0              1    14.23        1.71
# 1              1    13.20        1.78
# 2              1    13.16        2.36
# 3              1    14.37        1.95
# 4              1    13.24        2.59
# ..           ...      ...         ...
# 173            3    13.71        5.65
# 174            3    13.40        3.91
# 175            3    13.27        4.28
# 176            3    13.17        2.59
# 177            3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(data['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.kdeplot(data['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict ={1:'red',3:'blue',2:'green'}
sns.scatterplot(x=data['Alcohol'], y=data['Malic acid'], hue=data['Class label'], palette=color_dict)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Malic acid'>

# %% [markdown]
# #Let's Start the real Process

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data.drop('Class label', axis=1),
                                                    data['Class label'],
                                                    test_size = 0.3,
                                                    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

scaler.fit(X_train)

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
np.round(X_train.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count    124.0       124.0
# mean      13.0         2.4
# std        0.8         1.1
# min       11.0         0.9
# 25%       12.4         1.6
# 50%       13.0         1.9
# 75%       13.6         3.2
# max       14.8         5.6

# %%
np.round(X_test_scaled.describe(), 1)
# Out:
#        Alcohol  Malic acid
# count     54.0        54.0
# mean       0.5         0.3
# std        0.2         0.2
# min        0.1        -0.0
# 25%        0.4         0.1
# 50%        0.5         0.2
# 75%        0.7         0.4
# max        1.0         1.0

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2, figsize=(12,5))

ax1.scatter(X_train['Alcohol'], X_train['Malic acid'],c =y_train)
ax1.set_title('Before Scaling')
ax2.scatter(X_train_scaled['Alcohol'], X_train_scaled['Malic acid'],c=y_train)
ax2.set_title('After Scaling')
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols = 2, figsize=(12,5))

#before Scaling
ax1.set_title('Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
sns.kdeplot(X_train['Malic acid'], ax=ax1)

# after Scaling

ax2.set_title('After Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
sns.kdeplot(X_train_scaled['Malic acid'], ax=ax2)
plt.show()

# %%
fig, (ax1,ax2)= plt.subplots(ncols=2, figsize=(12,5))

#before scaling
ax1.set_title('Alcohol Distribution Before Scaling')
sns.kdeplot(X_train['Alcohol'], ax=ax1)
ax2.set_title('Alcohol Distribution After Scaling')
sns.kdeplot(X_train_scaled['Alcohol'], ax=ax2)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, figsize=(12,5))

# before scaling

ax1.set_title("Malic Acid Before Scaling")
sns.kdeplot(X_train["Malic acid"], ax=ax1)

# after scaling

ax2.set_title('Malic Acid After Standard Scaling')
sns.kdeplot(X_train_scaled["Malic acid"], ax=ax2)
plt.show()

# %%
username = "Pratk-sharma-py"
repository = "datascience"
# token removed for security

# Clone the repo into Colab
# token removed for security
# Out:
# Cloning into '{datascience}'...
# fatal: unable to access 'https://://github.com{Pratik-sharam-py}/{datascience}.git/': URL using bad/illegal format or missing URL
