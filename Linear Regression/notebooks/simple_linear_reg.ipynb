# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\LOQ\Desktop\Machine Learning\Linear Regression\data\raw\placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('PACKAGE(in LPA)')
# Out:
# Text(0, 0.5, 'PACKAGE(in LPA)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,1:2]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
Prediction = lr.predict(X_test)

# %%
y_test.head()
# Out:
#      package
# 112     4.10
# 29      3.49
# 182     2.08
# 199     2.33
# 193     1.94

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('PACKAGE(in LPA)')
# Out:
# Text(0, 0.5, 'PACKAGE(in LPA)')

# %%
m = lr.coef_
m
# Out:
# array([[0.55795197]])

# %%
b = lr.intercept_
b
# Out:
# array([-0.89611192])

# %%
# y = mx + b
y = m*6.89 + b
y
# Out:
# array([[2.94817717]])
