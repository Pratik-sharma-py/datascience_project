# %%
"""import re

def text_inspect(text):
    text = str(text)  # handle NaN safely

    report = {
        'length': len(text),
        'has_lowercase': bool(re.search(r"[a-z]", text)),
        'has_uppercase': bool(re.search(r"[A-Z]", text)),
        'has_extra_spaces': bool(re.search(r"\s{2,}", text)),
        'has_new_lines': "\n" in text,
        'has_tabs': "\t" in text,
        'has_urls': bool(re.search(r"https?://\S+|www\.\S+", text)),
        'has_email': bool(re.search(r"\b[\w\.-]+@[\w\.-]+\.\w+\b", text)),
        'has_mentions': bool(re.search(r"@\w+", text)),
        'has_hashtags': bool(re.search(r"#\w+", text)),
        'has_html_tags': bool(re.search(r"<[^>]+>", text)),
        'has_repeated_letters': bool(re.search(r"(.)\1{2,}", text)),
        'has_digits': bool(re.search(r"\d", text)),
        'has_emojis_or_non_ascii': any(ord(ch) > 127 for ch in text),
        'punctuation_count': len(re.findall(r"[^\w\s]", text)),
    }
    return report
for name, text in raw_text.items():
  print(f"===={name}======")
  pprint(text_inspect(text))
  print()
"""

# %%
#raw_text['message'] = raw_text['message'].str.lower()
#raw_text['message']

# %%
"""import re

def remove_html_tags(text):
    if not isinstance(text, str):
        return text  # or return "" if you want to clean NaN completely

    pattern = re.compile(r"<.*?>")
    return pattern.sub("", text)

raw_text = raw_text.apply(remove_html_tags)"""

# %%
# To remove URLs

"""def remove_url(text):
  if not isinstance(text,str):
    return text
  pattern = re.compile(r'https?://\S+|www\.\S+')
  return pattern.sub(r'', text)

raw_text = raw_text.apply(remove_url)"""

# %%
#import string
#string.punctuation

#exclude = string.punctuation

# %%
"""def remove_punc(text):
  if not isinstance(text,str):
    return text
  return text.translate(str.maketrans('','',exclude))


raw_text = raw_text.apply(remove_punc)
raw_text"""

# %%
"""def remove_extra_spaces(text):
    return re.sub(r"\s+", " ", str(text)).strip()  # Convert to string first

raw_text['message'] = raw_text['message'].apply(remove_extra_spaces)
raw_text['message'].head()"""

# %%
"""def normalize_unicode(text):
    return unicodedata.normalize("NFKC", text)

raw_text['message'] = raw_text['message'].apply(normalize_unicode)"""

# %%
"""def remove_emails(text):
    return re.sub(r"\b[\w\.-]+@[\w\.-]+\.\w+\b", " ", text)

raw_text['message'] = raw_text['message'].apply(remove_emails)"""

# %%
"""def remove_hashtags_mentions(text):
    text = re.sub(r"#\w+", " ", text)
    text = re.sub(r"@\w+", " ", text)
    return text

raw_text['message'] = raw_text['message'].apply(remove_hashtags_mentions)   """

# %%
"""def remove_special_characters(text):
    # Keep letters, numbers, and spaces only
    return re.sub(r"[^a-zA-Z0-9\s]", " ", text)

raw_text['message'] = raw_text['message'].apply(remove_special_characters) """

# %%
#import nltk

# %%
"""from nltk.corpus import stopwords

def remove_stopwords(text):
    x = []
    for i in text.split():
        if i not in stopwords.words('english'):
            x.append(i)
    y = x[:]
    x.clear()
    return y"""

# %%
#raw_text

# %%
"""def clean_and_stem(text):
    text = str(text).lower()
    text = re.sub(r"\s+", " ", text).strip()
    words = text.split()
    stemmed = [os.stem(word) for word in words]
    return " ".join(stemmed)

raw_text['message'] = raw_text['message'].apply(clean_and_stem)
print(raw_text['message'].head())"""

# %%
"""from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score

#L = [500,1000,1500,2000,2500,3000,3500,4000]
#for i in L:
cv = CountVectorizer(max_features=2000)
print(cv)
X = cv.fit_transform(raw_text['message']).toarray()
y = raw_text['category'].values
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
#clf1 = GaussianNB()
clf2 = MultinomialNB()
#clf3 = BernoulliNB()
#clf1.fit(X_train, y_train.astype(int))
clf2.fit(X_train, y_train.astype(int))
#clf3.fit(X_train, y_train.astype(int))
#y_pred1 = clf1.predict(X_test)
y_pred2 = clf2.predict(X_test)
#y_pred3 = clf3.predict(X_test)
#print("Gaussion",accuracy_score(y_test.astype(int),y_pred1))
print("Multinomial",accuracy_score(y_test.astype(int),y_pred2))
#print("Bernaulli",accuracy_score(y_test.astype(int),y_pred3))
    
   """

# %%
"""import pickle

pickle.dump(cv, open('cv.pkl', 'wb'))
pickle.dump(clf2, open('clf.pkl', 'wb'))"""

# %%
#X = cv.fit_transform(raw_text['message']).toarray()
# splitting of data
#from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
#from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
#clf1 = GaussianNB()
#clf2 = MultinomialNB()
#clf3 = BernoulliNB()
#clf1.fit(X_train, y_train.astype(int))
#clf2.fit(X_train, y_train.astype(int))
#clf3.fit(X_train, y_train.astype(int))
#print(y_test.shape)
#print(y_pred1.shape)
#from sklearn.metrics import accuracy_score
#print("Gaussion",accuracy_score(y_test.astype(int),y_pred1))
#print("Multinomial",accuracy_score(y_test.astype(int),y_pred2))
#print("Bernaulli",accuracy_score(y_test.astype(int),y_pred3))
